# %%
import tushare as ts
pro=ts.pro_api("31049f21293446a570aa825eb540a1507e766c0caa62f87ffbae2da0")
df1=pro.daily(ts_code='002950.SZ',start_date='20200101',end_date='20200414')
df2=pro.daily(ts_code='300030.SZ',start_date='20200101',end_date='20200414')
df3=pro.daily(ts_code='000652.SZ',start_date='20200101',end_date='20200414')

# %%
df1
# Out:
#       ts_code trade_date   open   high    low  close  pre_close  change  \
# 0   002950.SZ   20200414  40.00  40.15  37.16  38.20      38.20    0.00
# 1   002950.SZ   20200413  35.84  38.87  35.55  38.20      35.83    2.37
# 2   002950.SZ   20200410  36.67  37.47  35.70  35.83      36.74   -0.91
# 3   002950.SZ   20200409  35.98  37.38  35.55  36.74      36.71    0.03
# 4   002950.SZ   20200408  37.00  37.66  36.40  36.71      37.80   -1.09
# ..        ...        ...    ...    ...    ...    ...        ...     ...
# 62  002950.SZ   20200108  21.01  22.88  20.81  22.22      21.06    1.16
# 63  002950.SZ   20200107  20.90  21.15  20.82  21.06      20.80    0.26
# 64  002950.SZ   20200106  20.67  20.98  20.51  20.80      20.79    0.01
# 65  002950.SZ   20200103  20.85  20.95  20.64  20.79      20.90   -0.11
# 66  002950.SZ   20200102  20.95  20.95  20.64  20.90      20.85    0.05
#
#     pct_chg        vol      amount
# 0    0.0000  148839.10  571671.078
# ...

# %%
df2
# Out:
#       ts_code trade_date   open   high    low  close  pre_close  change  \
# 0   300030.SZ   20200414  10.99  11.00  10.55  10.78      10.90   -0.12
# 1   300030.SZ   20200413  10.50  11.08  10.45  10.90      10.87    0.03
# 2   300030.SZ   20200410  11.35  11.78  10.84  10.87      11.50   -0.63
# 3   300030.SZ   20200409  11.10  11.60  10.92  11.50      11.23    0.27
# 4   300030.SZ   20200408  11.67  11.67  11.10  11.23      11.85   -0.62
# ..        ...        ...    ...    ...    ...    ...        ...     ...
# 62  300030.SZ   20200108   7.25   7.44   7.18   7.22       7.31   -0.09
# 63  300030.SZ   20200107   7.23   7.33   7.16   7.31       7.23    0.08
# 64  300030.SZ   20200106   7.17   7.32   7.06   7.23       7.28   -0.05
# 65  300030.SZ   20200103   7.28   7.46   7.27   7.28       7.31   -0.03
# 66  300030.SZ   20200102   7.18   7.37   7.14   7.31       7.13    0.18
#
#     pct_chg        vol      amount
# 0   -1.1009  190536.05  204262.550
# ...

# %%
#close_data_middle

# %%
import pandas as pd
import cufflinks as cf
import numpy as np
close_data_aomeiyiliao=df1[['trade_date','close']]
close_data_yangpuyiliao=df2[['trade_date','close']]
close_data_taidagufen=df3[['trade_date','close']]
close_data_aomeiyiliao.columns=['trade_date','AoMei']
close_data_yangpuyiliao.columns=['trade_date','Yangpu']
close_data_taidagufen.columns=['trade_date','TaiDa']
close_data_middle=pd.merge(close_data_aomeiyiliao,close_data_yangpuyiliao,on="trade_date")
close_data_final=pd.merge(close_data_middle,close_data_taidagufen,on ="trade_date")
close_data_final.trade_date=pd.to_datetime(close_data_final.trade_date)
close_data_final.set_index(["trade_date"], inplace=True)
# #close_data_final

close_data_final.iplot(theme='pearl', filename='Tutorial Metadata', title='Chinese Mask Companies Stock Price',xTitle='Date', yTitle='Stock Price', world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="ab077a9a-aa23-4c8d-88b8-da9ac8babd65" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %%
import matplotlib.pyplot as plt
Global= (r"C:\Everything\Data\2020Spring\Datavis\New folder\COVID-19-master\csse_covid_19_data\csse_covid_19_time_series\time_series_covid19_confirmed_global.csv")        
df = pd.read_csv(Global)

# %%
df_china=df[df['Country/Region']=="China"]
#df_china

# %%
y=df_china.iloc[0:33,4:89].sum()
x=df_china.columns[4:89]

# %%
plt.figure()
plt.plot(x,y,'y.-')
plt.title('Number of COVID-19 China Confirmed')
plt.xticks(['1/22/20', '2/7/20', '2/20/20','3/9/20'],['Jan 22','Feb 07', 'Feb 20','Mar 09'])
# Out:
# ([<matplotlib.axis.XTick at 0x12c54331a88>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %%
import pandas as pd
from alpha_vantage.timeseries import TimeSeries
import time
# Invoke the live data from alpha_vantage 
api_key ='V5EIFADVL3GSTZK0'

ts=TimeSeries(key=api_key,output_format='pandas')
data,meta_data=ts.get_daily(symbol='MMM')

close_data=data['4. close']
close_data=close_data.head(72)
import cufflinks as cf
import numpy as np

close_data.iplot(theme='pearl', filename='Tutorial Metadata', title='3M Mask Company Stock Price',
         xTitle='Date', yTitle='Stock Price', world_readable=True)
data,meta_data
# Out:
# <div>
#
#
#             <div id="9bfee987-18a3-4072-bb34-f48fe3425926" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9bfee987-18a3-4072-bb34-f48fe3425926")) {
#                     Plotly.newPlot(
#                         '9bfee987-18a3-4072-bb34-f48fe3425926',
# ...

# %%
#ts1=TimeSeries(key=api_key,output_format='pandas')
#data1,meta_data1=ts.get_daily(symbol='.DJI')
#close_data1=data1['4. close']
#close_data1=close_data1.head(72)
# close_data1
#close_data1.iplot(theme='pearl', filename='Tutorial Metadata', title='Dow Jones Industrial Average',
#          xTitle='Date', yTitle='Index', world_readable=True)

# %%
import matplotlib.pyplot as plt
USA= (r"C:\Everything\Data\2020Spring\Datavis\New folder\COVID-19-master\csse_covid_19_data\csse_covid_19_time_series\time_series_covid19_confirmed_US.csv")        
df_usa = pd.read_csv(USA)
df_usa
# Out:
#              UID iso2 iso3  code3     FIPS  \
# 0           16.0   AS  ASM     16     60.0
# 1          316.0   GU  GUM    316     66.0
# 2          580.0   MP  MNP    580     69.0
# 3          630.0   PR  PRI    630     72.0
# 4          850.0   VI  VIR    850     78.0
# ...          ...  ...  ...    ...      ...
# 3251  84090056.0   US  USA    840  90056.0
# 3252  84099999.0   US  USA    840  99999.0
# 3253  84070004.0   US  USA    840      NaN
# 3254  84070005.0   US  USA    840      NaN
# 3255         NaN   US  USA    840      NaN
#
#                                          Admin2            Province_State  \
# 0                                           NaN            American Samoa
# 1                                           NaN                      Guam
# 2                                           NaN  Northern Mariana Islands
# 3                                           NaN               Puerto Rico
# ...

# %%
y_usa=df_usa.iloc[0:3256,11:89].sum()

x_usa=df_usa.columns[11:89]

# %%
plt.figure()
plt.plot(x_usa,y_usa,'y.-')
plt.title('Number of COVID-19 USA Confirmed')
plt.xticks(['1/22/20','3/23/20'],['Jan 22','Mar 23'])
# Out:
# ([<matplotlib.axis.XTick at 0x12c57b715c8>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
segments = ['Safety and industrial','Transportation and electronics','Health Care','Consumer','Corporat and unallocated']
revenue = [11607,9602,7431,5081,110]
GradeList = zip(segments,revenue)
columns=['Segments', 'Revenue']
df = pd.DataFrame(data = GradeList, columns=columns)
df
plt.pie(df['Revenue'],
labels=df['Segments'],
explode=(0,0,0.25,0,0),
startangle=90,
autopct='%1.1f%%',)
plt.axis('equal')
plt.title('3M Revenue by Business Segment in 2019')
plt.show()
